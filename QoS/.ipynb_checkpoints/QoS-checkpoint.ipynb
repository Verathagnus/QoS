# %%
! sudo apt-get -y install graphicsmagick
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono ghostscript gsfonts libcupsfilters1
#   libcupsimage2 libgraphicsmagick-q16-3 libgs9 libgs9-common libijs-0.35
#   libjbig2dec0 libpaper-utils libpaper1 libwmf0.2-7
# Suggested packages:
#   fonts-noto ghostscript-x graphicsmagick-dbg libwmf0.2-7-gtk
# The following NEW packages will be installed:
#   fonts-droid-fallback fonts-noto-mono ghostscript graphicsmagick gsfonts
#   libcupsfilters1 libcupsimage2 libgraphicsmagick-q16-3 libgs9 libgs9-common
#   libijs-0.35 libjbig2dec0 libpaper-utils libpaper1 libwmf0.2-7
# 0 upgraded, 15 newly installed, 0 to remove and 122 not upgraded.
# Need to get 14.5 MB of archives.
# After this operation, 46.8 MB of additional disk space will be used.
# Get:1 http://ap-northeast-2.ec2.archive.ubuntu.com/ubuntu bionic/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1 [1805 kB]
# Get:2 http://ap-northeast-2.ec2.archive.ubuntu.com/ubuntu bionic/main amd64 fonts-noto-mono all 20171026-2 [75.5 kB]
# Get:3 http://ap-northeast-2.ec2.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsimage2 amd64 2.2.7-1ubuntu2.8 [18.6 kB]
# Get:4 http://ap-northeast-2.ec2.archive.ubuntu.com/ubuntu bionic/main amd64 libijs-0.35 amd64 0.35-13 [15.5 kB]
# Get:5 http://ap-northeast-2.ec2.archive.ubuntu.com/ubuntu bionic/main amd64 libjbig2dec0 amd64 0.13-6 [55.9 kB]
# Get:6 http://ap-northeast-2.ec2.archive.ubuntu.com/ubuntu bionic/main amd64 libpaper1 amd64 1.1.24+nmu5ubuntu1 [13.6 kB]
# Get:7 http://ap-northeast-2.ec2.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9-common all 9.26~dfsg+0-0ubuntu0.18.04.13 [5092 kB]
# Get:8 http://ap-northeast-2.ec2.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9 amd64 9.26~dfsg+0-0ubuntu0.18.04.13 [2263 kB]
# Get:9 http://ap-northeast-2.ec2.archive.ubuntu.com/ubuntu bionic-updates/main amd64 ghostscript amd64 9.26~dfsg+0-0ubuntu0.18.04.13 [51.0 kB]
# Get:10 http://ap-northeast-2.ec2.archive.ubuntu.com/ubuntu bionic/main amd64 libwmf0.2-7 amd64 0.2.8.4-12 [150 kB]
# Get:11 http://ap-northeast-2.ec2.archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libgraphicsmagick-q16-3 amd64 1.3.28-2ubuntu0.1 [1116 kB]
# Get:12 http://ap-northeast-2.ec2.archive.ubuntu.com/ubuntu bionic-updates/universe amd64 graphicsmagick amd64 1.3.28-2ubuntu0.1 [634 kB]
# Get:13 http://ap-northeast-2.ec2.archive.ubuntu.com/ubuntu bionic/main amd64 gsfonts all 1:8.11+urwcyr1.0.7~pre44-4.4 [3120 kB]
# Get:14 http://ap-northeast-2.ec2.archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsfilters1 amd64 1.20.2-0ubuntu3.1 [108 kB]
# Get:15 http://ap-northeast-2.ec2.archive.ubuntu.com/ubuntu bionic/main amd64 libpaper-utils amd64 1.1.24+nmu5ubuntu1 [8170 B]
# Fetched 14.5 MB in 3s (4856 kB/s)
# perl: warning: Setting locale failed.
# perl: warning: Please check that your locale settings:
# 	LANGUAGE = "en_US.UTF-8",
# 	LC_ALL = (unset),
# 	LC_CTYPE = "C.UTF-8",
# 	LANG = "en_US.UTF-8"
#     are supported and installed on your system.
# perl: warning: Falling back to the standard locale ("C").
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 15.)
# debconf: falling back to frontend: Readline
# Preconfiguring packages ...
# Selecting previously unselected package fonts-droid-fallback.
# (Reading database ... 97521 files and directories currently installed.)
# Preparing to unpack .../00-fonts-droid-fallback_1%3a6.0.1r16-1.1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../01-fonts-noto-mono_20171026-2_all.deb ...
# Unpacking fonts-noto-mono (20171026-2) ...
# Selecting previously unselected package libcupsimage2:amd64.
# Preparing to unpack .../02-libcupsimage2_2.2.7-1ubuntu2.8_amd64.deb ...
# Unpacking libcupsimage2:amd64 (2.2.7-1ubuntu2.8) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../03-libijs-0.35_0.35-13_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-13) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../04-libjbig2dec0_0.13-6_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.13-6) ...
# Selecting previously unselected package libpaper1:amd64.
# Preparing to unpack .../05-libpaper1_1.1.24+nmu5ubuntu1_amd64.deb ...
# Unpacking libpaper1:amd64 (1.1.24+nmu5ubuntu1) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../06-libgs9-common_9.26~dfsg+0-0ubuntu0.18.04.13_all.deb ...
# Unpacking libgs9-common (9.26~dfsg+0-0ubuntu0.18.04.13) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../07-libgs9_9.26~dfsg+0-0ubuntu0.18.04.13_amd64.deb ...
# Unpacking libgs9:amd64 (9.26~dfsg+0-0ubuntu0.18.04.13) ...
# Selecting previously unselected package ghostscript.
# Preparing to unpack .../08-ghostscript_9.26~dfsg+0-0ubuntu0.18.04.13_amd64.deb ...
# Unpacking ghostscript (9.26~dfsg+0-0ubuntu0.18.04.13) ...
# Selecting previously unselected package libwmf0.2-7:amd64.
# Preparing to unpack .../09-libwmf0.2-7_0.2.8.4-12_amd64.deb ...
# Unpacking libwmf0.2-7:amd64 (0.2.8.4-12) ...
# Selecting previously unselected package libgraphicsmagick-q16-3.
# Preparing to unpack .../10-libgraphicsmagick-q16-3_1.3.28-2ubuntu0.1_amd64.deb ...
# Unpacking libgraphicsmagick-q16-3 (1.3.28-2ubuntu0.1) ...
# Selecting previously unselected package graphicsmagick.
# Preparing to unpack .../11-graphicsmagick_1.3.28-2ubuntu0.1_amd64.deb ...
# Unpacking graphicsmagick (1.3.28-2ubuntu0.1) ...
# Selecting previously unselected package gsfonts.
# Preparing to unpack .../12-gsfonts_1%3a8.11+urwcyr1.0.7~pre44-4.4_all.deb ...
# Unpacking gsfonts (1:8.11+urwcyr1.0.7~pre44-4.4) ...
# Selecting previously unselected package libcupsfilters1:amd64.
# Preparing to unpack .../13-libcupsfilters1_1.20.2-0ubuntu3.1_amd64.deb ...
# Unpacking libcupsfilters1:amd64 (1.20.2-0ubuntu3.1) ...
# Selecting previously unselected package libpaper-utils.
# Preparing to unpack .../14-libpaper-utils_1.1.24+nmu5ubuntu1_amd64.deb ...
# Unpacking libpaper-utils (1.1.24+nmu5ubuntu1) ...
# Setting up libgs9-common (9.26~dfsg+0-0ubuntu0.18.04.13) ...
# Setting up libpaper1:amd64 (1.1.24+nmu5ubuntu1) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
#
# Creating config file /etc/papersize with new version
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Setting up libpaper-utils (1.1.24+nmu5ubuntu1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Setting up gsfonts (1:8.11+urwcyr1.0.7~pre44-4.4) ...
# Setting up fonts-noto-mono (20171026-2) ...
# Setting up libcupsfilters1:amd64 (1.20.2-0ubuntu3.1) ...
# Setting up libcupsimage2:amd64 (2.2.7-1ubuntu2.8) ...
# Setting up libjbig2dec0:amd64 (0.13-6) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Setting up libijs-0.35:amd64 (0.35-13) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Setting up libgs9:amd64 (9.26~dfsg+0-0ubuntu0.18.04.13) ...
# Setting up libwmf0.2-7:amd64 (0.2.8.4-12) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Setting up ghostscript (9.26~dfsg+0-0ubuntu0.18.04.13) ...
# Setting up libgraphicsmagick-q16-3 (1.3.28-2ubuntu0.1) ...
# Setting up graphicsmagick (1.3.28-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...

# %%
from __future__ import print_function
import numpy as np
import re
import sys
import math
import scipy.misc
import subprocess
import os.path
import imageio
import vifp
import psnr
import ssim
import reco
import cv2 as cv
import argparse
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

def getPSNR(I1, I2):
    s1 = cv.absdiff(I1, I2) #|I1 - I2|
    s1 = np.float32(s1)     # cannot make a square on 8 bits
    s1 = s1 * s1            # |I1 - I2|^2
    sse = s1.sum()          # sum elements per channel
    if sse <= 1e-10:        # sum channels
        return 0            # for small values return zero
    else:
        shape = I1.shape
        mse = 1.0 * sse / (shape[0] * shape[1] * shape[2])
        psnr = 10.0 * np.log10((255 * 255) / mse)
        return psnr

def getMSSISM(i1, i2):
    C1 = 6.5025
    C2 = 58.5225
    # INITS
    I1 = np.float32(i1)
    I2 = np.float32(i2)
    I2_2 = I2 * I2
    I1_2 = I1 * I1
    I1_I2 = I1 * I2
    mu1 = cv.GaussianBlur(I1, (11, 11), 1.5)
    mu2 = cv.GaussianBlur(I2, (11, 11), 1.5)
    mu1_2 = mu1 * mu1
    mu2_2 = mu2 * mu2
    mu1_mu2 = mu1 * mu2
    sigma1_2 = cv.GaussianBlur(I1_2, (11, 11), 1.5)
    sigma1_2 -= mu1_2
    sigma2_2 = cv.GaussianBlur(I2_2, (11, 11), 1.5)
    sigma2_2 -= mu2_2
    sigma12 = cv.GaussianBlur(I1_I2, (11, 11), 1.5)
    sigma12 -= mu1_mu2
    t1 = 2 * mu1_mu2 + C1
    t2 = 2 * sigma12 + C2
    t3 = t1 * t2
    t1 = mu1_2 + mu2_2 + C1
    t2 = sigma1_2 + sigma2_2 + C2
    t1 = t1 * t2
    ssim_map = cv.divide(t3, t1)
    mssim = cv.mean(ssim_map)      
    return mssim

# %%
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))
# Loop0
# Loop1
# Loop2
# Loop3
# Loop4

# %%
ref_file = 'lena.png'
dist_file = 'lena_tmp.jpg'

ref = imageio.imread(ref_file, as_gray=True).astype(np.float32)

quality_values = []
size_values = []
vifp_values = []
ssim_values = []
psnr_values = []
reco_values = []
# mssim_values = []



for quality in tqdm(range(0, 101, 1)):
    # !gm convert $ref_file -quality $quality $dist_file
#     subprocess.check_call('gm convert %s -quality %d %s'%(ref_file, quality, dist_file), shell=True)
#     subprocess.check_call('gm convert {} -quality {} {}'.format(ref_file, quality, dist_file), shell=True)
    file_size = os.path.getsize(dist_file)

    dist = imageio.imread(dist_file, as_gray=True).astype(np.float32)

    quality_values.append( quality )
    size_values.append( int(file_size/1024) )
    vifp_values.append( vifp.vifp_mscale(ref, dist) )
    ssim_values.append( ssim.ssim_exact(ref/255, dist/255) )
    psnr_values.append( psnr.psnr(ref, dist) )
    reco_values.append( reco.reco(ref/255, dist/255) )
#     mssim_values.append( getMSSISM(ref/255, dist/255) )

plt.figure(figsize=(8, 8))
plt.plot(quality_values, vifp_values, label='VIFP')
plt.plot(quality_values, ssim_values, label='SSIM')
# plt.plot(quality_values, mssim_values, label='MSSIM')
plt.plot(quality_values, reco_values, label='RECO')
plt.plot(quality_values, np.asarray(psnr_values)/100.0, label='PSNR/100')
plt.legend(loc='lower right')
plt.xlabel('JPEG Quality')
plt.ylabel('Metric')
plt.savefig('jpg_demo_quality.png')

plt.figure(figsize=(8, 8))

plt.plot(size_values, vifp_values, label='VIFP')
plt.plot(size_values, ssim_values, label='SSIM')
# plt.plot(size_values, mssim_values, label='MSSIM')
plt.plot(size_values, reco_values, label='RECO')
plt.plot(size_values, np.asarray(psnr_values)/100.0, label='PSNR/100')
plt.legend(loc='lower right')
plt.xlabel('JPEG File Size, KB')
plt.ylabel('Metric')
plt.savefig('jpg_demo_size.png')
# Out:
# /bin/bash: -c: line 1: syntax error: unexpected end of file
# Loop0
# /bin/bash: -c: line 1: syntax error: unexpected end of file
# Loop1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-d067d23f1cbe> in <module>
#      29     ssim_values.append( ssim.ssim_exact(ref/255, dist/255) )
#      30     psnr_values.append( psnr.psnr(ref, dist) )
# ---> 31     reco_values.append( reco.reco(ref/255, dist/255) )
#      32 #     mssim_values.append( getMSSISM(ref/255, dist/255) )
#      33
#
# /workspace/video-quality/QoS/reco.py in reco(img1, img2)
#      85 def reco(img1, img2):
#      86     C = 1 # TODO what is a good value?
# ---> 87     return (eco(img2) + C) / (eco(img1) + C)
#      88
#
# /workspace/video-quality/QoS/reco.py in eco(img)
#      75     l30 = Laguerre_Gauss_Circular_Harmonic_3_0(17, 2)
#      76     y10 = scipy.ndimage.filters.convolve(img, numpy.real(l10)) + 1j * scipy.ndimage.filters.convolve(img, numpy.imag(l10))
# ---> 77     y30 = scipy.ndimage.filters.convolve(img, numpy.real(l30)) + 1j * scipy.ndimage.filters.convolve(img, numpy.imag(l30))
#      78     eco = numpy.sum( - (numpy.absolute(y30) * numpy.absolute(y10)) * numpy.cos( numpy.angle(y30) - 3 * numpy.angle(y10) ) )
#      79     return eco
#
# /usr/local/lib/python3.7/site-packages/scipy/ndimage/filters.py in convolve(input, weights, output, mode, cval, origin)
#     800     """
#     801     return _correlate_or_convolve(input, weights, output, mode, cval,
# --> 802                                   origin, True)
#     803
#     804
#
# /usr/local/lib/python3.7/site-packages/scipy/ndimage/filters.py in _correlate_or_convolve(input, weights, output, mode, cval, origin, convolution)
#     627         raise RuntimeError("A sequence of modes is not supported")
#     628     mode = _ni_support._extend_mode_to_code(mode)
# --> 629     _nd_image.correlate(input, weights, output, mode, cval, origins)
#     630     if temp_needed:
#     631         temp[...] = output
#
# KeyboardInterrupt:
